# %% [markdown]
# <a href="https://colab.research.google.com/github/Singati2/AI_Science_Medicine/blob/main/Copy_of_Plotting_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
points = 10
data= np.random.rand(points, 2)
data
data= np.random.rand(3, 3)
np.random.rand(3, 3)
plt.imshow(data, cmap="gray")
RGB_data = np.random.rand(300, 300,3)
plt.imshow(RGB_data)

# %%
import numpy as np
import matplotlib.pyplot as plt
points = 10
data= np.random.rand(points, 2)
data
data= np.random.rand(3, 3)
np.random.rand(3, 3)
plt.imshow(data, cmap="hot")
RGB_data = np.random.rand(2000, 2000,3)
plt.imshow(RGB_data)
